# %%
import cv2
from ultralytics import solutions

cap = cv2.VideoCapture("3641366019-preview.mp4")
assert cap.isOpened(), "Error reading video file"

# Video writer
w, h, fps = (int(cap.get(x)) for x in (cv2.CAP_PROP_FRAME_WIDTH, cv2.CAP_PROP_FRAME_HEIGHT, cv2.CAP_PROP_FPS))
video_writer = cv2.VideoWriter("heatmap_output.avi", cv2.VideoWriter_fourcc(*"mp4v"), fps, (w, h))


heatmap = solutions.Heatmap(
    show=True,  
    model="C:/Users/USER/Desktop/vision/yolov5/runs/train2/weights/best.pt", 
    colormap=cv2.COLORMAP_PARULA,

)

# Process video
while cap.isOpened():
    success, im0 = cap.read()

    if not success:
        print("Video frame is empty or processing is complete.")
        break

    results = heatmap(im0)

    print(results)  

    video_writer.write(results.plot_im)  

cap.release()
video_writer.release()
cv2.destroyAllWindows()
# Out:
# Ultralytics Solutions:  {'region': None, 'show_in': True, 'show_out': True, 'colormap': 12, 'up_angle': 145.0, 'down_angle': 90, 'kpts': [6, 8, 10], 'analytics_type': 'line', 'json_file': None, 'records': 5, 'show': True, 'model': 'C:/Users/USER/Desktop/vision/yolov5/runs/train2/weights/best.pt'}
#
# 0: 480x640 6 persons, 27.4ms
# Speed: 4.5ms preprocess, 27.4ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=6)
# SolutionResults(total_tracks=6)
#
# 0: 480x640 5 persons, 11.5ms
# Speed: 3.4ms preprocess, 11.5ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 5 persons, 11.7ms
# Speed: 3.1ms preprocess, 11.7ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 5 persons, 17.5ms
# Speed: 2.3ms preprocess, 17.5ms inference, 9.7ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 5 persons, 17.9ms
# Speed: 3.1ms preprocess, 17.9ms inference, 11.6ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 5 persons, 12.7ms
# Speed: 2.4ms preprocess, 12.7ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 5 persons, 7.8ms
# Speed: 2.2ms preprocess, 7.8ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 5 persons, 7.3ms
# Speed: 1.8ms preprocess, 7.3ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 4 persons, 14.5ms
# Speed: 2.3ms preprocess, 14.5ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=4)
# SolutionResults(total_tracks=4)
#
# 0: 480x640 4 persons, 7.3ms
# Speed: 1.6ms preprocess, 7.3ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=4)
# SolutionResults(total_tracks=4)
#
# 0: 480x640 5 persons, 8.3ms
# Speed: 1.6ms preprocess, 8.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 4 persons, 7.2ms
# Speed: 3.2ms preprocess, 7.2ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=4)
# SolutionResults(total_tracks=4)
#
# 0: 480x640 4 persons, 13.4ms
# Speed: 2.2ms preprocess, 13.4ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=4)
# SolutionResults(total_tracks=4)
#
# 0: 480x640 4 persons, 7.2ms
# Speed: 1.7ms preprocess, 7.2ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=4)
# SolutionResults(total_tracks=4)
#
# 0: 480x640 4 persons, 7.7ms
# Speed: 1.7ms preprocess, 7.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=4)
# SolutionResults(total_tracks=4)
#
# 0: 480x640 4 persons, 7.1ms
# Speed: 2.0ms preprocess, 7.1ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=4)
# SolutionResults(total_tracks=4)
#
# 0: 480x640 5 persons, 7.9ms
# Speed: 1.9ms preprocess, 7.9ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 5 persons, 6.9ms
# Speed: 1.7ms preprocess, 6.9ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 5 persons, 7.9ms
# Speed: 2.0ms preprocess, 7.9ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 5 persons, 7.1ms
# Speed: 1.6ms preprocess, 7.1ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 5 persons, 6.9ms
# Speed: 1.7ms preprocess, 6.9ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 5 persons, 7.7ms
# Speed: 1.6ms preprocess, 7.7ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 6 persons, 6.4ms
# Speed: 1.7ms preprocess, 6.4ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=6)
# SolutionResults(total_tracks=6)
#
# 0: 480x640 6 persons, 6.6ms
# Speed: 1.8ms preprocess, 6.6ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=6)
# SolutionResults(total_tracks=6)
#
# 0: 480x640 6 persons, 7.1ms
# Speed: 2.6ms preprocess, 7.1ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=6)
# SolutionResults(total_tracks=6)
#
# 0: 480x640 6 persons, 6.7ms
# Speed: 1.7ms preprocess, 6.7ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=6)
# SolutionResults(total_tracks=6)
#
# 0: 480x640 6 persons, 13.0ms
# Speed: 1.6ms preprocess, 13.0ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=6)
# SolutionResults(total_tracks=6)
#
# 0: 480x640 6 persons, 6.3ms
# Speed: 1.7ms preprocess, 6.3ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=6)
# SolutionResults(total_tracks=6)
#
# 0: 480x640 5 persons, 6.3ms
# Speed: 1.9ms preprocess, 6.3ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 5 persons, 14.0ms
# Speed: 4.7ms preprocess, 14.0ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 5 persons, 7.7ms
# Speed: 2.6ms preprocess, 7.7ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 6 persons, 6.5ms
# Speed: 1.7ms preprocess, 6.5ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=6)
# SolutionResults(total_tracks=6)
#
# 0: 480x640 6 persons, 14.6ms
# Speed: 3.9ms preprocess, 14.6ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=6)
# SolutionResults(total_tracks=6)
#
# 0: 480x640 5 persons, 8.3ms
# Speed: 2.3ms preprocess, 8.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 5 persons, 28.7ms
# Speed: 7.7ms preprocess, 28.7ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 5 persons, 7.2ms
# Speed: 1.8ms preprocess, 7.2ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 5 persons, 10.6ms
# Speed: 2.6ms preprocess, 10.6ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 5 persons, 13.8ms
# Speed: 3.7ms preprocess, 13.8ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 5 persons, 16.9ms
# Speed: 3.5ms preprocess, 16.9ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 5 persons, 6.4ms
# Speed: 2.3ms preprocess, 6.4ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 5 persons, 6.8ms
# Speed: 2.3ms preprocess, 6.8ms inference, 4.3ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 5 persons, 7.0ms
# Speed: 1.9ms preprocess, 7.0ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 5 persons, 6.6ms
# Speed: 2.2ms preprocess, 6.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 4 persons, 10.9ms
# Speed: 2.4ms preprocess, 10.9ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=4)
# SolutionResults(total_tracks=4)
#
# 0: 480x640 4 persons, 17.0ms
# Speed: 7.9ms preprocess, 17.0ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=4)
# SolutionResults(total_tracks=4)
#
# 0: 480x640 4 persons, 10.7ms
# Speed: 5.7ms preprocess, 10.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=4)
# SolutionResults(total_tracks=4)
#
# 0: 480x640 4 persons, 7.1ms
# Speed: 1.9ms preprocess, 7.1ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=4)
# SolutionResults(total_tracks=4)
#
# 0: 480x640 5 persons, 6.9ms
# Speed: 1.8ms preprocess, 6.9ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 5 persons, 6.6ms
# Speed: 1.9ms preprocess, 6.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 5 persons, 18.1ms
# Speed: 3.5ms preprocess, 18.1ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 5 persons, 11.1ms
# Speed: 4.1ms preprocess, 11.1ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 5 persons, 15.7ms
# Speed: 6.5ms preprocess, 15.7ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 5 persons, 6.5ms
# Speed: 3.0ms preprocess, 6.5ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 5 persons, 7.5ms
# Speed: 2.4ms preprocess, 7.5ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 4 persons, 10.1ms
# Speed: 2.0ms preprocess, 10.1ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=4)
# SolutionResults(total_tracks=4)
#
# 0: 480x640 4 persons, 8.4ms
# Speed: 2.0ms preprocess, 8.4ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=4)
# SolutionResults(total_tracks=4)
#
# 0: 480x640 5 persons, 15.3ms
# Speed: 2.7ms preprocess, 15.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 5 persons, 6.2ms
# Speed: 2.0ms preprocess, 6.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 5 persons, 11.4ms
# Speed: 7.3ms preprocess, 11.4ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 5 persons, 8.6ms
# Speed: 2.7ms preprocess, 8.6ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 5 persons, 6.8ms
# Speed: 1.9ms preprocess, 6.8ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 5 persons, 14.5ms
# Speed: 2.3ms preprocess, 14.5ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 4 persons, 6.4ms
# Speed: 2.1ms preprocess, 6.4ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=4)
# SolutionResults(total_tracks=4)
#
# 0: 480x640 5 persons, 10.0ms
# Speed: 3.5ms preprocess, 10.0ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 5 persons, 20.3ms
# Speed: 3.9ms preprocess, 20.3ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 5 persons, 6.3ms
# Speed: 1.9ms preprocess, 6.3ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 4 persons, 10.2ms
# Speed: 2.5ms preprocess, 10.2ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=4)
# SolutionResults(total_tracks=4)
#
# 0: 480x640 4 persons, 8.3ms
# Speed: 2.4ms preprocess, 8.3ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=4)
# SolutionResults(total_tracks=4)
#
# 0: 480x640 4 persons, 13.6ms
# Speed: 4.4ms preprocess, 13.6ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=4)
# SolutionResults(total_tracks=4)
#
# 0: 480x640 4 persons, 21.3ms
# Speed: 9.7ms preprocess, 21.3ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=4)
# SolutionResults(total_tracks=4)
#
# 0: 480x640 5 persons, 7.0ms
# Speed: 2.5ms preprocess, 7.0ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 5 persons, 26.2ms
# Speed: 7.3ms preprocess, 26.2ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 5 persons, 10.5ms
# Speed: 2.3ms preprocess, 10.5ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 4 persons, 14.4ms
# Speed: 3.0ms preprocess, 14.4ms inference, 4.4ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=4)
# SolutionResults(total_tracks=4)
#
# 0: 480x640 4 persons, 11.8ms
# Speed: 3.9ms preprocess, 11.8ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=4)
# SolutionResults(total_tracks=4)
#
# 0: 480x640 3 persons, 16.3ms
# Speed: 2.7ms preprocess, 16.3ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=3)
# SolutionResults(total_tracks=3)
#
# 0: 480x640 5 persons, 13.8ms
# Speed: 2.8ms preprocess, 13.8ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 6 persons, 12.6ms
# Speed: 5.3ms preprocess, 12.6ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=6)
# SolutionResults(total_tracks=6)
#
# 0: 480x640 4 persons, 12.1ms
# Speed: 4.6ms preprocess, 12.1ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=4)
# SolutionResults(total_tracks=4)
#
# 0: 480x640 4 persons, 10.2ms
# Speed: 2.8ms preprocess, 10.2ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=4)
# SolutionResults(total_tracks=4)
#
# 0: 480x640 5 persons, 22.7ms
# Speed: 4.8ms preprocess, 22.7ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 4 persons, 18.4ms
# Speed: 7.1ms preprocess, 18.4ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=4)
# SolutionResults(total_tracks=4)
#
# 0: 480x640 3 persons, 8.3ms
# Speed: 2.1ms preprocess, 8.3ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=3)
# SolutionResults(total_tracks=3)
#
# 0: 480x640 3 persons, 8.4ms
# Speed: 3.0ms preprocess, 8.4ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=3)
# SolutionResults(total_tracks=3)
#
# 0: 480x640 3 persons, 12.6ms
# Speed: 3.1ms preprocess, 12.6ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=3)
# SolutionResults(total_tracks=3)
#
# 0: 480x640 6 persons, 8.0ms
# Speed: 2.2ms preprocess, 8.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=6)
# SolutionResults(total_tracks=6)
#
# 0: 480x640 6 persons, 7.1ms
# Speed: 2.7ms preprocess, 7.1ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=6)
# SolutionResults(total_tracks=6)
#
# 0: 480x640 6 persons, 7.5ms
# Speed: 1.9ms preprocess, 7.5ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=6)
# SolutionResults(total_tracks=6)
#
# 0: 480x640 6 persons, 11.6ms
# Speed: 5.6ms preprocess, 11.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=6)
# SolutionResults(total_tracks=6)
#
# 0: 480x640 5 persons, 16.8ms
# Speed: 1.9ms preprocess, 16.8ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 5 persons, 6.5ms
# Speed: 2.2ms preprocess, 6.5ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 6 persons, 12.5ms
# Speed: 3.3ms preprocess, 12.5ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=6)
# SolutionResults(total_tracks=6)
#
# 0: 480x640 6 persons, 12.8ms
# Speed: 3.5ms preprocess, 12.8ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=6)
# SolutionResults(total_tracks=6)
#
# 0: 480x640 6 persons, 6.8ms
# Speed: 1.8ms preprocess, 6.8ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=6)
# SolutionResults(total_tracks=6)
#
# 0: 480x640 6 persons, 10.3ms
# Speed: 1.6ms preprocess, 10.3ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=6)
# SolutionResults(total_tracks=6)
#
# 0: 480x640 6 persons, 6.9ms
# Speed: 1.7ms preprocess, 6.9ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=6)
# SolutionResults(total_tracks=6)
#
# 0: 480x640 6 persons, 6.9ms
# Speed: 1.7ms preprocess, 6.9ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=6)
# SolutionResults(total_tracks=6)
#
# 0: 480x640 6 persons, 10.1ms
# Speed: 1.8ms preprocess, 10.1ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=6)
# SolutionResults(total_tracks=6)
#
# 0: 480x640 5 persons, 7.1ms
# Speed: 2.2ms preprocess, 7.1ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 7 persons, 6.8ms
# Speed: 2.0ms preprocess, 6.8ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=7)
# SolutionResults(total_tracks=7)
#
# 0: 480x640 7 persons, 6.8ms
# Speed: 1.7ms preprocess, 6.8ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=7)
# SolutionResults(total_tracks=7)
#
# 0: 480x640 7 persons, 6.5ms
# Speed: 1.6ms preprocess, 6.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=7)
# SolutionResults(total_tracks=7)
#
# 0: 480x640 7 persons, 11.1ms
# Speed: 1.6ms preprocess, 11.1ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=7)
# SolutionResults(total_tracks=7)
#
# 0: 480x640 7 persons, 6.3ms
# Speed: 2.0ms preprocess, 6.3ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=7)
# SolutionResults(total_tracks=7)
#
# 0: 480x640 6 persons, 6.5ms
# Speed: 2.0ms preprocess, 6.5ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=6)
# SolutionResults(total_tracks=6)
#
# 0: 480x640 7 persons, 6.7ms
# Speed: 1.7ms preprocess, 6.7ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=7)
# SolutionResults(total_tracks=7)
#
# 0: 480x640 7 persons, 7.4ms
# Speed: 1.9ms preprocess, 7.4ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=7)
# SolutionResults(total_tracks=7)
#
# 0: 480x640 7 persons, 6.2ms
# Speed: 1.7ms preprocess, 6.2ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=7)
# SolutionResults(total_tracks=7)
#
# 0: 480x640 8 persons, 6.4ms
# Speed: 1.6ms preprocess, 6.4ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=8)
# SolutionResults(total_tracks=8)
#
# 0: 480x640 5 persons, 8.3ms
# Speed: 1.9ms preprocess, 8.3ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 5 persons, 6.8ms
# Speed: 2.1ms preprocess, 6.8ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 5 persons, 7.1ms
# Speed: 1.7ms preprocess, 7.1ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 7 persons, 6.6ms
# Speed: 1.7ms preprocess, 6.6ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=7)
# SolutionResults(total_tracks=7)
#
# 0: 480x640 7 persons, 6.1ms
# Speed: 1.6ms preprocess, 6.1ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=7)
# SolutionResults(total_tracks=7)
#
# 0: 480x640 7 persons, 8.1ms
# Speed: 2.1ms preprocess, 8.1ms inference, 4.8ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=7)
# SolutionResults(total_tracks=7)
#
# 0: 480x640 6 persons, 6.0ms
# Speed: 2.2ms preprocess, 6.0ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=6)
# SolutionResults(total_tracks=6)
#
# 0: 480x640 6 persons, 9.7ms
# Speed: 2.1ms preprocess, 9.7ms inference, 5.2ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=6)
# SolutionResults(total_tracks=6)
#
# 0: 480x640 6 persons, 6.5ms
# Speed: 2.6ms preprocess, 6.5ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=6)
# SolutionResults(total_tracks=6)
#
# 0: 480x640 6 persons, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 5.3ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=6)
# SolutionResults(total_tracks=6)
#
# 0: 480x640 5 persons, 8.6ms
# Speed: 2.2ms preprocess, 8.6ms inference, 4.4ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 6 persons, 6.1ms
# Speed: 2.9ms preprocess, 6.1ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=6)
# SolutionResults(total_tracks=6)
#
# 0: 480x640 6 persons, 20.2ms
# Speed: 7.9ms preprocess, 20.2ms inference, 5.7ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=6)
# SolutionResults(total_tracks=6)
#
# 0: 480x640 5 persons, 8.9ms
# Speed: 2.3ms preprocess, 8.9ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 5 persons, 7.8ms
# Speed: 2.3ms preprocess, 7.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 5 persons, 13.9ms
# Speed: 2.7ms preprocess, 13.9ms inference, 4.9ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 5 persons, 7.1ms
# Speed: 1.9ms preprocess, 7.1ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 5 persons, 8.0ms
# Speed: 1.9ms preprocess, 8.0ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 5 persons, 11.3ms
# Speed: 2.2ms preprocess, 11.3ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 5 persons, 11.5ms
# Speed: 2.0ms preprocess, 11.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 5 persons, 11.1ms
# Speed: 2.7ms preprocess, 11.1ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 5 persons, 8.5ms
# Speed: 1.8ms preprocess, 8.5ms inference, 5.1ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 5 persons, 6.5ms
# Speed: 1.8ms preprocess, 6.5ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 5 persons, 7.7ms
# Speed: 1.8ms preprocess, 7.7ms inference, 5.8ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 5 persons, 10.3ms
# Speed: 3.3ms preprocess, 10.3ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 5 persons, 7.2ms
# Speed: 2.0ms preprocess, 7.2ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 5 persons, 15.1ms
# Speed: 2.5ms preprocess, 15.1ms inference, 7.0ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 5 persons, 10.1ms
# Speed: 2.0ms preprocess, 10.1ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 5 persons, 7.2ms
# Speed: 2.9ms preprocess, 7.2ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 5 persons, 8.3ms
# Speed: 2.3ms preprocess, 8.3ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 5 persons, 14.6ms
# Speed: 1.9ms preprocess, 14.6ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 5 persons, 12.6ms
# Speed: 3.6ms preprocess, 12.6ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 6 persons, 14.6ms
# Speed: 3.3ms preprocess, 14.6ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=6)
# SolutionResults(total_tracks=6)
#
# 0: 480x640 5 persons, 11.4ms
# Speed: 3.9ms preprocess, 11.4ms inference, 5.1ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 5 persons, 8.6ms
# Speed: 2.5ms preprocess, 8.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 5 persons, 7.0ms
# Speed: 2.5ms preprocess, 7.0ms inference, 5.1ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 5 persons, 13.0ms
# Speed: 2.2ms preprocess, 13.0ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 5 persons, 9.1ms
# Speed: 2.9ms preprocess, 9.1ms inference, 5.3ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 5 persons, 19.2ms
# Speed: 3.1ms preprocess, 19.2ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 5 persons, 10.4ms
# Speed: 2.7ms preprocess, 10.4ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 6 persons, 14.8ms
# Speed: 3.3ms preprocess, 14.8ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=6)
# SolutionResults(total_tracks=6)
#
# 0: 480x640 6 persons, 20.3ms
# Speed: 6.2ms preprocess, 20.3ms inference, 3.4ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=6)
# SolutionResults(total_tracks=6)
#
# 0: 480x640 6 persons, 13.7ms
# Speed: 7.0ms preprocess, 13.7ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=6)
# SolutionResults(total_tracks=6)
#
# 0: 480x640 7 persons, 9.3ms
# Speed: 3.4ms preprocess, 9.3ms inference, 4.3ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=7)
# SolutionResults(total_tracks=7)
#
# 0: 480x640 7 persons, 7.4ms
# Speed: 1.9ms preprocess, 7.4ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=7)
# SolutionResults(total_tracks=7)
#
# 0: 480x640 6 persons, 8.5ms
# Speed: 2.0ms preprocess, 8.5ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=6)
# SolutionResults(total_tracks=6)
#
# 0: 480x640 6 persons, 12.5ms
# Speed: 3.0ms preprocess, 12.5ms inference, 6.5ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=6)
# SolutionResults(total_tracks=6)
#
# 0: 480x640 7 persons, 8.9ms
# Speed: 3.3ms preprocess, 8.9ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=7)
# SolutionResults(total_tracks=7)
#
# 0: 480x640 6 persons, 8.7ms
# Speed: 3.1ms preprocess, 8.7ms inference, 5.8ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=6)
# SolutionResults(total_tracks=6)
#
# 0: 480x640 6 persons, 12.4ms
# Speed: 2.8ms preprocess, 12.4ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=6)
# SolutionResults(total_tracks=6)
#
# 0: 480x640 6 persons, 13.9ms
# Speed: 3.9ms preprocess, 13.9ms inference, 5.8ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=6)
# SolutionResults(total_tracks=6)
#
# 0: 480x640 7 persons, 10.0ms
# Speed: 3.1ms preprocess, 10.0ms inference, 5.9ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=7)
# SolutionResults(total_tracks=7)
#
# 0: 480x640 7 persons, 9.1ms
# Speed: 2.6ms preprocess, 9.1ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=7)
# SolutionResults(total_tracks=7)
#
# 0: 480x640 6 persons, 11.2ms
# Speed: 4.5ms preprocess, 11.2ms inference, 5.6ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=6)
# SolutionResults(total_tracks=6)
#
# 0: 480x640 6 persons, 12.9ms
# Speed: 3.5ms preprocess, 12.9ms inference, 5.9ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=6)
# SolutionResults(total_tracks=6)
#
# 0: 480x640 6 persons, 6.9ms
# Speed: 2.2ms preprocess, 6.9ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=6)
# SolutionResults(total_tracks=6)
#
# 0: 480x640 5 persons, 11.5ms
# Speed: 6.1ms preprocess, 11.5ms inference, 5.6ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 6 persons, 8.6ms
# Speed: 3.2ms preprocess, 8.6ms inference, 5.9ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=6)
# SolutionResults(total_tracks=6)
#
# 0: 480x640 7 persons, 12.2ms
# Speed: 3.6ms preprocess, 12.2ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=7)
# SolutionResults(total_tracks=7)
#
# 0: 480x640 6 persons, 10.7ms
# Speed: 2.1ms preprocess, 10.7ms inference, 5.7ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=6)
# SolutionResults(total_tracks=6)
#
# 0: 480x640 7 persons, 15.6ms
# Speed: 2.2ms preprocess, 15.6ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=7)
# SolutionResults(total_tracks=7)
#
# 0: 480x640 7 persons, 6.6ms
# Speed: 1.7ms preprocess, 6.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=7)
# SolutionResults(total_tracks=7)
#
# 0: 480x640 7 persons, 10.5ms
# Speed: 1.8ms preprocess, 10.5ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=7)
# SolutionResults(total_tracks=7)
#
# 0: 480x640 7 persons, 7.7ms
# Speed: 2.4ms preprocess, 7.7ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=7)
# SolutionResults(total_tracks=7)
#
# 0: 480x640 7 persons, 6.5ms
# Speed: 1.6ms preprocess, 6.5ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=7)
# SolutionResults(total_tracks=7)
#
# 0: 480x640 7 persons, 7.0ms
# Speed: 2.7ms preprocess, 7.0ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=7)
# SolutionResults(total_tracks=7)
#
# 0: 480x640 6 persons, 7.9ms
# Speed: 2.2ms preprocess, 7.9ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=6)
# SolutionResults(total_tracks=6)
#
# 0: 480x640 6 persons, 7.3ms
# Speed: 1.8ms preprocess, 7.3ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=6)
# SolutionResults(total_tracks=6)
#
# 0: 480x640 6 persons, 8.3ms
# Speed: 2.5ms preprocess, 8.3ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=6)
# SolutionResults(total_tracks=6)
#
# 0: 480x640 6 persons, 9.8ms
# Speed: 3.4ms preprocess, 9.8ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=6)
# SolutionResults(total_tracks=6)
#
# 0: 480x640 6 persons, 6.2ms
# Speed: 2.6ms preprocess, 6.2ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=6)
# SolutionResults(total_tracks=6)
#
# 0: 480x640 6 persons, 11.8ms
# Speed: 4.4ms preprocess, 11.8ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=6)
# SolutionResults(total_tracks=6)
#
# 0: 480x640 6 persons, 24.9ms
# Speed: 5.2ms preprocess, 24.9ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=6)
# SolutionResults(total_tracks=6)
#
# 0: 480x640 6 persons, 18.9ms
# Speed: 4.4ms preprocess, 18.9ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=6)
# SolutionResults(total_tracks=6)
#
# 0: 480x640 6 persons, 6.4ms
# Speed: 1.9ms preprocess, 6.4ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=6)
# SolutionResults(total_tracks=6)
#
# 0: 480x640 7 persons, 11.7ms
# Speed: 2.4ms preprocess, 11.7ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=7)
# SolutionResults(total_tracks=7)
#
# 0: 480x640 8 persons, 10.8ms
# Speed: 1.9ms preprocess, 10.8ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=8)
# SolutionResults(total_tracks=8)
#
# 0: 480x640 7 persons, 8.3ms
# Speed: 1.9ms preprocess, 8.3ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=7)
# SolutionResults(total_tracks=7)
#
# 0: 480x640 6 persons, 8.0ms
# Speed: 2.3ms preprocess, 8.0ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=6)
# SolutionResults(total_tracks=6)
#
# 0: 480x640 5 persons, 11.6ms
# Speed: 2.3ms preprocess, 11.6ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 4 persons, 6.6ms
# Speed: 1.6ms preprocess, 6.6ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=4)
# SolutionResults(total_tracks=4)
#
# 0: 480x640 4 persons, 10.6ms
# Speed: 2.9ms preprocess, 10.6ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=4)
# SolutionResults(total_tracks=4)
#
# 0: 480x640 4 persons, 13.4ms
# Speed: 1.8ms preprocess, 13.4ms inference, 4.9ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=4)
# SolutionResults(total_tracks=4)
#
# 0: 480x640 4 persons, 7.6ms
# Speed: 1.6ms preprocess, 7.6ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=4)
# SolutionResults(total_tracks=4)
#
# 0: 480x640 5 persons, 11.3ms
# Speed: 2.4ms preprocess, 11.3ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 5 persons, 11.5ms
# Speed: 2.7ms preprocess, 11.5ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 5 persons, 13.1ms
# Speed: 3.3ms preprocess, 13.1ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 5 persons, 6.8ms
# Speed: 2.4ms preprocess, 6.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 7 persons, 11.0ms
# Speed: 2.4ms preprocess, 11.0ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=7)
# SolutionResults(total_tracks=7)
#
# 0: 480x640 6 persons, 7.0ms
# Speed: 1.9ms preprocess, 7.0ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=6)
# SolutionResults(total_tracks=6)
#
# 0: 480x640 6 persons, 6.9ms
# Speed: 1.9ms preprocess, 6.9ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=6)
# SolutionResults(total_tracks=6)
#
# 0: 480x640 6 persons, 13.1ms
# Speed: 2.7ms preprocess, 13.1ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=6)
# SolutionResults(total_tracks=6)
#
# 0: 480x640 5 persons, 15.1ms
# Speed: 5.7ms preprocess, 15.1ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 5 persons, 7.2ms
# Speed: 3.7ms preprocess, 7.2ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 5 persons, 18.0ms
# Speed: 5.0ms preprocess, 18.0ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 5 persons, 8.6ms
# Speed: 2.7ms preprocess, 8.6ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 5 persons, 16.0ms
# Speed: 4.7ms preprocess, 16.0ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 5 persons, 12.0ms
# Speed: 3.4ms preprocess, 12.0ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 4 persons, 12.0ms
# Speed: 6.4ms preprocess, 12.0ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=4)
# SolutionResults(total_tracks=4)
#
# 0: 480x640 5 persons, 8.0ms
# Speed: 1.9ms preprocess, 8.0ms inference, 5.6ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 5 persons, 12.9ms
# Speed: 4.7ms preprocess, 12.9ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 5 persons, 7.1ms
# Speed: 1.8ms preprocess, 7.1ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 6 persons, 8.6ms
# Speed: 2.0ms preprocess, 8.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=6)
# SolutionResults(total_tracks=6)
#
# 0: 480x640 6 persons, 11.0ms
# Speed: 2.8ms preprocess, 11.0ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=6)
# SolutionResults(total_tracks=6)
#
# 0: 480x640 6 persons, 8.9ms
# Speed: 1.9ms preprocess, 8.9ms inference, 5.8ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=6)
# SolutionResults(total_tracks=6)
#
# 0: 480x640 7 persons, 7.2ms
# Speed: 2.0ms preprocess, 7.2ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=7)
# SolutionResults(total_tracks=7)
#
# 0: 480x640 6 persons, 15.7ms
# Speed: 3.1ms preprocess, 15.7ms inference, 4.3ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=6)
# SolutionResults(total_tracks=6)
#
# 0: 480x640 6 persons, 7.9ms
# Speed: 2.1ms preprocess, 7.9ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=6)
# SolutionResults(total_tracks=6)
#
# 0: 480x640 5 persons, 8.1ms
# Speed: 3.3ms preprocess, 8.1ms inference, 5.4ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 6 persons, 11.1ms
# Speed: 3.2ms preprocess, 11.1ms inference, 4.8ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=6)
# SolutionResults(total_tracks=6)
#
# 0: 480x640 6 persons, 7.5ms
# Speed: 2.2ms preprocess, 7.5ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=6)
# SolutionResults(total_tracks=6)
#
# 0: 480x640 5 persons, 11.5ms
# Speed: 2.7ms preprocess, 11.5ms inference, 4.3ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 5 persons, 13.2ms
# Speed: 2.1ms preprocess, 13.2ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 5 persons, 9.1ms
# Speed: 2.0ms preprocess, 9.1ms inference, 6.1ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 5 persons, 9.7ms
# Speed: 2.0ms preprocess, 9.7ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 7 persons, 16.0ms
# Speed: 2.7ms preprocess, 16.0ms inference, 4.8ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=7)
# SolutionResults(total_tracks=7)
#
# 0: 480x640 6 persons, 8.3ms
# Speed: 2.1ms preprocess, 8.3ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=6)
# SolutionResults(total_tracks=6)
#
# 0: 480x640 6 persons, 8.9ms
# Speed: 2.0ms preprocess, 8.9ms inference, 5.7ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=6)
# SolutionResults(total_tracks=6)
#
# 0: 480x640 6 persons, 8.2ms
# Speed: 2.0ms preprocess, 8.2ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=6)
# SolutionResults(total_tracks=6)
#
# 0: 480x640 5 persons, 14.1ms
# Speed: 3.2ms preprocess, 14.1ms inference, 4.9ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 5 persons, 10.6ms
# Speed: 3.5ms preprocess, 10.6ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 5 persons, 10.3ms
# Speed: 5.3ms preprocess, 10.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 4 persons, 23.9ms
# Speed: 7.1ms preprocess, 23.9ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=4)
# SolutionResults(total_tracks=4)
#
# 0: 480x640 3 persons, 23.5ms
# Speed: 3.6ms preprocess, 23.5ms inference, 9.2ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=3)
# SolutionResults(total_tracks=3)
#
# 0: 480x640 4 persons, 8.8ms
# Speed: 3.4ms preprocess, 8.8ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=4)
# SolutionResults(total_tracks=4)
#
# 0: 480x640 4 persons, 11.8ms
# Speed: 2.1ms preprocess, 11.8ms inference, 6.4ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=4)
# SolutionResults(total_tracks=4)
#
# 0: 480x640 4 persons, 8.4ms
# Speed: 2.9ms preprocess, 8.4ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=4)
# SolutionResults(total_tracks=4)
#
# 0: 480x640 4 persons, 9.8ms
# Speed: 3.8ms preprocess, 9.8ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=4)
# SolutionResults(total_tracks=4)
#
# 0: 480x640 4 persons, 8.8ms
# Speed: 2.6ms preprocess, 8.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=4)
# SolutionResults(total_tracks=4)
#
# 0: 480x640 4 persons, 15.6ms
# Speed: 3.6ms preprocess, 15.6ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=4)
# SolutionResults(total_tracks=4)
#
# 0: 480x640 4 persons, 9.9ms
# Speed: 2.1ms preprocess, 9.9ms inference, 4.4ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=4)
# SolutionResults(total_tracks=4)
#
# 0: 480x640 4 persons, 8.5ms
# Speed: 2.0ms preprocess, 8.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=4)
# SolutionResults(total_tracks=4)
#
# 0: 480x640 4 persons, 13.0ms
# Speed: 2.1ms preprocess, 13.0ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=4)
# SolutionResults(total_tracks=4)
#
# 0: 480x640 4 persons, 10.0ms
# Speed: 2.8ms preprocess, 10.0ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=4)
# SolutionResults(total_tracks=4)
#
# 0: 480x640 3 persons, 8.8ms
# Speed: 3.0ms preprocess, 8.8ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=3)
# SolutionResults(total_tracks=3)
#
# 0: 480x640 4 persons, 9.2ms
# Speed: 2.0ms preprocess, 9.2ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=4)
# SolutionResults(total_tracks=4)
#
# 0: 480x640 6 persons, 8.8ms
# Speed: 2.8ms preprocess, 8.8ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=6)
# SolutionResults(total_tracks=6)
#
# 0: 480x640 6 persons, 13.6ms
# Speed: 3.4ms preprocess, 13.6ms inference, 6.6ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=6)
# SolutionResults(total_tracks=6)
#
# 0: 480x640 6 persons, 12.5ms
# Speed: 2.1ms preprocess, 12.5ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=6)
# SolutionResults(total_tracks=6)
#
# 0: 480x640 6 persons, 9.3ms
# Speed: 2.0ms preprocess, 9.3ms inference, 6.7ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=6)
# SolutionResults(total_tracks=6)
#
# 0: 480x640 6 persons, 8.8ms
# Speed: 2.0ms preprocess, 8.8ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=6)
# SolutionResults(total_tracks=6)
#
# 0: 480x640 7 persons, 9.9ms
# Speed: 2.2ms preprocess, 9.9ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=7)
# SolutionResults(total_tracks=7)
#
# 0: 480x640 6 persons, 11.5ms
# Speed: 2.7ms preprocess, 11.5ms inference, 6.4ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=6)
# SolutionResults(total_tracks=6)
#
# 0: 480x640 6 persons, 11.8ms
# Speed: 2.2ms preprocess, 11.8ms inference, 6.3ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=6)
# SolutionResults(total_tracks=6)
#
# 0: 480x640 6 persons, 9.1ms
# Speed: 2.0ms preprocess, 9.1ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=6)
# SolutionResults(total_tracks=6)
#
# 0: 480x640 6 persons, 13.5ms
# Speed: 2.3ms preprocess, 13.5ms inference, 7.2ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=6)
# SolutionResults(total_tracks=6)
#
# 0: 480x640 6 persons, 9.6ms
# Speed: 2.2ms preprocess, 9.6ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=6)
# SolutionResults(total_tracks=6)
#
# 0: 480x640 6 persons, 10.2ms
# Speed: 2.6ms preprocess, 10.2ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=6)
# SolutionResults(total_tracks=6)
#
# 0: 480x640 7 persons, 11.6ms
# Speed: 2.8ms preprocess, 11.6ms inference, 7.0ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=7)
# SolutionResults(total_tracks=7)
#
# 0: 480x640 7 persons, 9.1ms
# Speed: 2.5ms preprocess, 9.1ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=7)
# SolutionResults(total_tracks=7)
#
# 0: 480x640 6 persons, 10.9ms
# Speed: 2.9ms preprocess, 10.9ms inference, 6.4ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=6)
# SolutionResults(total_tracks=6)
#
# 0: 480x640 6 persons, 12.1ms
# Speed: 4.3ms preprocess, 12.1ms inference, 6.7ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=6)
# SolutionResults(total_tracks=6)
#
# 0: 480x640 6 persons, 13.5ms
# Speed: 2.9ms preprocess, 13.5ms inference, 6.3ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=6)
# SolutionResults(total_tracks=6)
#
# 0: 480x640 6 persons, 8.6ms
# Speed: 2.9ms preprocess, 8.6ms inference, 7.2ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=6)
# SolutionResults(total_tracks=6)
#
# 0: 480x640 6 persons, 9.6ms
# Speed: 2.8ms preprocess, 9.6ms inference, 7.1ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=6)
# SolutionResults(total_tracks=6)
#
# 0: 480x640 6 persons, 8.5ms
# Speed: 3.1ms preprocess, 8.5ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=6)
# SolutionResults(total_tracks=6)
#
# 0: 480x640 5 persons, 9.8ms
# Speed: 2.0ms preprocess, 9.8ms inference, 5.8ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 5 persons, 14.3ms
# Speed: 2.6ms preprocess, 14.3ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 5 persons, 9.0ms
# Speed: 1.9ms preprocess, 9.0ms inference, 6.4ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 5 persons, 9.1ms
# Speed: 4.4ms preprocess, 9.1ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 6 persons, 10.0ms
# Speed: 2.3ms preprocess, 10.0ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=6)
# SolutionResults(total_tracks=6)
#
# 0: 480x640 6 persons, 9.1ms
# Speed: 2.6ms preprocess, 9.1ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=6)
# SolutionResults(total_tracks=6)
#
# 0: 480x640 5 persons, 9.8ms
# Speed: 5.2ms preprocess, 9.8ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 5 persons, 15.5ms
# Speed: 2.8ms preprocess, 15.5ms inference, 6.2ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 5 persons, 9.7ms
# Speed: 2.8ms preprocess, 9.7ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 5 persons, 9.0ms
# Speed: 2.5ms preprocess, 9.0ms inference, 7.6ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 5 persons, 14.2ms
# Speed: 5.4ms preprocess, 14.2ms inference, 6.1ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 5 persons, 8.9ms
# Speed: 2.3ms preprocess, 8.9ms inference, 6.6ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 5 persons, 8.7ms
# Speed: 3.5ms preprocess, 8.7ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 5 persons, 14.8ms
# Speed: 2.9ms preprocess, 14.8ms inference, 2.9ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 5 persons, 10.3ms
# Speed: 3.7ms preprocess, 10.3ms inference, 6.5ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 5 persons, 7.7ms
# Speed: 3.3ms preprocess, 7.7ms inference, 5.6ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 5 persons, 10.0ms
# Speed: 2.9ms preprocess, 10.0ms inference, 6.2ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 5 persons, 7.7ms
# Speed: 2.5ms preprocess, 7.7ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 5 persons, 8.8ms
# Speed: 2.5ms preprocess, 8.8ms inference, 6.2ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 5 persons, 12.8ms
# Speed: 3.7ms preprocess, 12.8ms inference, 6.4ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 5 persons, 10.4ms
# Speed: 3.3ms preprocess, 10.4ms inference, 5.9ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 4 persons, 11.4ms
# Speed: 3.5ms preprocess, 11.4ms inference, 6.1ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=4)
# SolutionResults(total_tracks=4)
#
# 0: 480x640 4 persons, 11.5ms
# Speed: 2.4ms preprocess, 11.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=4)
# SolutionResults(total_tracks=4)
#
# 0: 480x640 5 persons, 9.2ms
# Speed: 2.7ms preprocess, 9.2ms inference, 3.8ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 5 persons, 7.7ms
# Speed: 2.4ms preprocess, 7.7ms inference, 6.4ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=5)
# SolutionResults(total_tracks=5)
#
# 0: 480x640 4 persons, 7.7ms
# Speed: 2.8ms preprocess, 7.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#  Results: SolutionResults(total_tracks=4)
# SolutionResults(total_tracks=4)
# Video frame is empty or processing is complete.
